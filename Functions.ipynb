# %% [markdown]
# Functions

# %% [markdown]
# Theory Questions

# %% [markdown]
# 1. What is the difference between a function and a method in Python?
#
# - Function: A block of code that does something, called by its name.
#   Example: print().
#   Method: A function that belongs to an object, called using object.method
#   Example: "hello".upper().
#
# 2. Explain the concept of function arguments and parameters in Python?
#
#   - Parameters: Names you define in a function to receive input. Example: def greet(name): (name is a parameter).
#    Arguments: Actual values you pass to a function when calling it. Example: greet("Alice") ("Alice" is an argument).
#
# 3.  What are the different ways to define and call a function in Python?
#   - Basic Function:
#    def greet():
#      print("Hello!")
#   Function with Parameters:
#   def greet(name):
#      print(f"Hello, {name}!")
#
#   - Calling Functions:
#      Basic Function:
#      greet()  # Output: Hello!
#      With Arguments:
#      greet("Alice")  # Output: Hello, Alice!
#
# 4. What is the purpose of the `return` statement in a Python function?
#
#   - Send a value from a function back to where it was called.
#      End the function immediately.
#      Ex: def add(a, b):
#      return a + b
#
# 5. What are iterators in Python and how do they differ from iterables ?
#
#   - Iterable: An object you can loop over, like a list, string, or tuple.
#      Example:  [1, 2, 3], "hello".
#      Iterable: Can be looped over but doesn’t remember where it left off.
#      Iterator: Tracks its position and provides the next value when asked.
#
# 6. Explain the concept of generators in Python and how they are defined?
#
#   - Generators: Special functions that produce values one at a time using the yield keyword, instead of returning them all at once.
#    Use yield instead of return.
#    gen = count_up_to(3)
#
#      print(next(gen))  # Output: 1
#      print(next(gen))  # Output: 2
#      print(next(gen))  # Output: 3
#
# 7. What are the advantages of using generators over regular functions ?
#
#   -  Save Memory
#      Lazy Evaluation
#      Simpler Code
#      Infinite Sequences
#
# 8.What is a lambda function in Python and when is it typically used ?
#
#  - A lambda function is a small, anonymous function with no name, defined using the lambda keyword.
#   It can take any number of inputs but has only one expression, which is returned automatically.
#   Example with:  map(), filter(), and sorted().
#
#
# 9.  Explain the purpose and usage of the `map()` function in Python?
#
#   - The map() function applies a given function to each item in an iterable (like a list) and returns a new iterable with the results.
#
#   function: The action you want to apply
#   e.g., square a number
#   iterable: The list or sequence to process.
#
# 10. What is the difference between `map()`, `reduce()`, and `filter()` functions in Python ?
#
# - map()
#
#   Purpose: Applies a function to each item in an iterable (like a list) and returns a new iterable with the results.
#
#   Ex: numbers = [1, 2, 3, 4]
# result = map(lambda x: x * 2, numbers)  # Doubles each number
# print(list(result))  # Output: [2, 4, 6, 8]
#
#  filter()
#
#  Purpose: Filters items in an iterable based on a condition (returns only the items that satisfy the condition).
#
#  Ex:numbers = [1, 2, 3, 4]
# result = filter(lambda x: x % 2 == 0, numbers)  # Keeps even numbers
# print(list(result))  # Output: [2, 4]
#
# reduce()
# Purpose: Combines all elements of an iterable into a single result using a function.
#   ex:
#   from functools import reduce
# numbers = [1, 2, 3, 4]
# result = reduce(lambda x, y: x + y, numbers)  # Adds all numbers
# print(result)  # Output: 10
#
# 11.  Using pen & Paper write the internal mechanism for sum operation using  reduce function on this given
# list:[47,11,42,13];
#
# - from functools import reduce
# numbers = [47, 11, 42, 13]
# result = reduce(lambda x, y: x + y, numbers)
# print(result)  # Output: 113

# %% [markdown]
# Practical Questions

# %%
#1.Write a Python function that takes a list of numbers as input and returns the sum of all even numbers in
the list?

   - def sum_of_even_numbers(numbers):
    """
    Takes a list of numbers and returns the sum of all even numbers.
    """
    return sum(num for num in numbers if num % 2 == 0)

# Example usage
numbers = [1, 2, 3, 4, 5, 6]
result = sum_of_even_numbers(numbers)
print(f"The sum of even numbers is: {result}")


#2. Create a Python function that accepts a string and returns the reverse of that string?

   - def reverse_string(s):
    """
    Accepts a string and returns its reverse.
    """
    return s[::-1]

# Example usage
text = "hello"
reversed_text = reverse_string(text)
print(f"The reverse of '{text}' is '{reversed_text}'")


#3. Implement a Python function that takes a list of integers and returns a new list containing the squares of
each number?

 - def square_numbers(numbers):
    """
    Takes a list of integers and returns a new list with the squares of each number.
    """
    return [num ** 2 for num in numbers]

# Example usage
numbers = [1, 2, 3, 4, 5]
squared_numbers = square_numbers(numbers)
print(f"The squares of {numbers} are {squared_numbers}")

#4.Write a Python function that checks if a given number is prime or not from 1 to 200?

  - def is_prime(num):
    """
    Checks if a number is prime.
    """
    if num < 2:
        return False  # Numbers less than 2 are not prime
    for i in range(2, int(num**0.5) + 1):
        if num % i == 0:
            return False  # If divisible by any number, it's not prime
    return True  # Otherwise, it's prime


#5.  Create an iterator class in Python that generates the Fibonacci sequence up to a specified number of
terms?

  - class FibonacciIterator:
    def __init__(self, n_terms):
        self.n_terms = n_terms
        self.a, self.b = 0, 1
        self.count = 0

    def __iter__(self):
        return self

    def __next__(self):
        if self.count >= self.n_terms:
            raise StopIteration
        self.count += 1
        result = self.a
        self.a, self.b = self.b, self.a + self.b
        return result

#6. Write a generator function in Python that yields the powers of 2 up to a given exponent?

  - def powers_of_two(max_exponent):
    """
    Yields powers of 2 from 2^0 up to 2^max_exponent.
    """
    for exponent in range(max_exponent + 1):
        yield 2 ** exponent

#7. Implement a generator function that reads a file line by line and yields each line as a string?

  - def read_file_line_by_line(file_path):
    """
    Reads a file line by line and yields each line as a string.
    """
    with open(file_path, 'r') as file:
        for line in file:
            yield line.strip()  # Using strip to remove any extra whitespace

#8. Use a lambda function in Python to sort a list of tuples based on the second element of each tuple?

  - # List of tuples to sort
tuples_list = [(3, 5), (1, 2), (4, 1), (2, 3)]

# Sort using a lambda function that sorts based on the second element of each tuple
sorted_list = sorted(tuples_list, key=lambda x: x[1])

# Output the sorted list
print(sorted_list)

#9.  Write a Python program that uses `map()` to convert a list of temperatures from Celsius to Fahrenheit?

  - def celsius_to_fahrenheit(celsius_temps):
    """
    Converts a list of temperatures from Celsius to Fahrenheit.
    """
    return list(map(lambda c: (c * 9/5) + 32, celsius_temps))

#10.  Create a Python program that uses `filter()` to remove all the vowels from a given string?

   - def remove_vowels(s):
    """
    Removes all vowels from a given string.
    """
    vowels = 'aeiouAEIOU'
    return ''.join(filter(lambda c: c not in vowels, s))

#11. Write a Python program, which returns a list with 2-tuples. Each tuple consists of the order number and the
product of the price per item and the quantity. The product should be increased by 10,- € if the value of the
order is smaller than 100,00 €.

Write a Python program using lambda and map

  -   List of orders
orders = [
    (34587, "Learning Python, Mark Lutz", 4, 40.95),
    (98762, "Programming Python, Mark Lutz", 5, 56.80),
    (77226, "Head First Python, Paul Barry", 3, 32.95),
    (88112, "Einfuhrung in Python3, Bernd Klein", 3, 24.99),
]

# Lambda function to calculate the total with the 10€ adjustment if below 100
calculate_total = lambda order: (order[0], order[2] * order[3] + (10 if order[2] * order[3] < 100 else 0))

# Use map to apply the calculation to each order
result = list(map(calculate_total, orders))

# Print the result
print(result)
